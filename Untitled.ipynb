# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# data =np.loadtxt('spec1.txt')
# energy = 1.240/data[:,1]
# ext = data[:,2]
# absorp = data[:,3]
# plt.plot(energy, ext,'o')

# idx = np.where(ext == max(ext))
# print(energy[idx])

# shape = np.loadtxt('shape.dat', skiprows=23)
# x = shape[:,1]
# y = shape[:,2]
# z = shape[:,3]
# plt.axis('equal')
# plt.scatter(x, z)

# field = np.loadtxt('ddfield.E_79', skiprows=25)
# plt.axis('equal')
# plt.title('.622 eV')
# # plt.scatter(field[:,0], field[:,2], c=field[:,5], cmap='seismic')
# plt.scatter(field[:,0], field[:,2], c=field[:,6], cmap='seismic')

# print(max(field[:,5]), max(field[:,6]))

# %%
# a= 1.4, 1.7, 1.8, 2.0
data =np.loadtxt('Spectrum_trimer_40-100_a2.75_at144',skiprows=1)
plt.plot(data[:,0], data[:,1])

data =np.loadtxt('Spectrum_trimer_40-100_a2.79_at144',skiprows=1)
plt.plot(data[:,0], data[:,1],'--')


plt.xlim([0.5, 2.25])
print(1240/(data[np.where(data[:,1] == max(data[:,1])), 0][0][0]))

# little = np.where(np.round(data[:,0],2)==1.71)[0][0]
# plt.plot(data[:little,0], data[:little, 1])
# print(1240/(data[np.where(data[:little,1] == max(data[:little,1])), 0][0][0]))
# Out:
# 688.506385341477
